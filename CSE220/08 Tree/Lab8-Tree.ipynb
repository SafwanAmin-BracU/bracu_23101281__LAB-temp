# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
    if root.left != None:
        convert_mirror(root.left)
    if root.right != None:
        convert_mirror(root.right)
    root.left, root.right = root.right, root.left
    return root



# DRIVER CODE


root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)


root.left = n1
root.right = n2


n1.left = n3
n1.right = n4



print("Given Tree Inorder Traversal: ", end=" ")
inorder(root)  # Given Tree Inorder Traversal:  40 20 60 10 30
print()


root2 = convert_mirror(root)
print("Mirrored Tree Inorder Traversal: ", end=" ")
inorder(root2)  # Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root, nLevel=0, levelsValueMap={}):
    if root == None:
        return levelsValueMap
    if nLevel in levelsValueMap:
        levelsValueMap[nLevel] = min(levelsValueMap[nLevel], root.elem)
    else:
        levelsValueMap[nLevel] = root.elem
    if root.left != None:
        smallest_level(root.left, nLevel + 1, levelsValueMap)
    if root.right != None:
        smallest_level(root.right, nLevel + 1, levelsValueMap)
    return levelsValueMap



# DRIVER CODE


root = tree_construction([None, 4, 9, 2, 3, -5, None, 7])
print("Given Tree Inorder Traversal: ", end=" ")
inorder(root)  # Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print("Level Wise Smallest Value: ", end=" ")
print(smallest_level(root))  # Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):

  return maximum(x.left)

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Workspace\BracU\LAB\CSE220\08 Tree\Lab8-Tree.ipynb Cell 9 line 2
#      <a href='vscode-notebook-cell:/d%3A/Workspace/BracU/LAB/CSE220/08%20Tree/Lab8-Tree.ipynb#X11sZmlsZQ%3D%3D?line=24'>25</a> print()
#      <a href='vscode-notebook-cell:/d%3A/Workspace/BracU/LAB/CSE220/08%20Tree/Lab8-Tree.ipynb#X11sZmlsZQ%3D%3D?line=26'>27</a> x = root
# ---> <a href='vscode-notebook-cell:/d%3A/Workspace/BracU/LAB/CSE220/08%20Tree/Lab8-Tree.ipynb#X11sZmlsZQ%3D%3D?line=27'>28</a> print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
#
# d:\Workspace\BracU\LAB\CSE220\08 Tree\Lab8-Tree.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/d%3A/Workspace/BracU/LAB/CSE220/08%20Tree/Lab8-Tree.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> def inorder_predecessor(root, x):
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/BracU/LAB/CSE220/08%20Tree/Lab8-Tree.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>   return maximum(x.left)
#
# NameError: name 'maximum' is not defined

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):
  pass
  return None

#DRIVER CODE
#Write by yourself from the given tree
#check all the sample inputs given

# %% [markdown]
# BONUS TASK 1

# %%
#WRITE THE FUNCTION and DRIVER CODE BY YOURSELF

# %% [markdown]
# Bonus Task 2

# %%
#WRITE THE FUNCTION BY YOURSELF

#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8
